# %% [markdown]
# # LCEL: LangChain Expression Language

# %%
import os
from dotenv import load_dotenv
from langchain_groq import ChatGroq
load_dotenv()

groq_api_key = os.environ["GROQ_API_KEY"]

model = ChatGroq(model="Gemma2-9b-It", groq_api_key=groq_api_key)
model
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x0000020E8A9DD6C0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000020E8A9DF250>, model_name='Gemma2-9b-It', groq_api_key=SecretStr('**********'))

# %%
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.output_parsers import StrOutputParser

messages = [
    SystemMessage(content="Translate the following from English to French. Don't give any additional information"),
    HumanMessage(content="Hello how are you?")
]

response = model.invoke(messages)
response
# Out:
# AIMessage(content='Salut, comment vas-tu ? \n', response_metadata={'token_usage': {'completion_tokens': 11, 'prompt_tokens': 29, 'total_tokens': 40, 'completion_time': 0.02, 'prompt_time': 0.003321875, 'queue_time': 0.24832480399999998, 'total_time': 0.023321875}, 'model_name': 'Gemma2-9b-It', 'system_fingerprint': 'fp_10c08bf97d', 'finish_reason': 'stop', 'logprobs': None}, id='run-642501cf-b5ae-4bc8-8737-a946c4644b4a-0', usage_metadata={'input_tokens': 29, 'output_tokens': 11, 'total_tokens': 40})

# %%
parser = StrOutputParser()
parser.invoke(response)
# Out:
# 'Salut, comment vas-tu ? \n'

# %%
from langchain.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system","Translate the following into: {language}. Don't give additional text."),
        ("user", "{text}")
    ]
)
prompt.invoke({"language":"French","text":"Hello?"})
# Out:
# ChatPromptValue(messages=[SystemMessage(content="Translate the following into: French. Don't give additional text."), HumanMessage(content='Hello?')])

# %%
# LCEL
chain = prompt|model|parser
chain.invoke({"language":"French","text":"Hello?"})
# Out:
# 'Bonjour ? \n'
